# %%
# Write a First LLM Application using Google Gemini

# %%
# !pip install -q -U google-generativeai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.1/163.1 kB 3.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 717.3/717.3 kB 18.4 MB/s eta 0:00:00

# %%
# !pip install ipython
# Out:
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (7.34.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython) (67.7.2)
# Collecting jedi>=0.16 (from ipython)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 16.9 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython) (3.0.47)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython) (0.2.13)
# Installing collected packages: jedi
# Successfully installed jedi-0.19.1

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown

def to_markdown(text):
  text = text.replace(".","*")
  return Markdown(textwrap.indent(text,'> ',predicate=lambda x:True))

# %%
from google.colab import userdata

GOOGLE_API_KEY = userdata.get("GOOGLE_API_KEY")
genai.configure(api_key=GOOGLE_API_KEY)

# %%
print(GOOGLE_API_KEY)
# Out:
# AIzaSyDeYxiJDAXJvn9JtcPiGDOnKO1mCUDMLMA

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-flash
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-latest
# models/gemini-1.5-pro
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision

# %%
model = genai.GenerativeModel('gemini-pro')
model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-pro',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
# %%time
print("This is the code to be timed")
# Out:
# This is the code to be timed
# CPU times: user 2.15 ms, sys: 8 µs, total: 2.16 ms
# Wall time: 2.08 ms

# %%
response = model.generate_content("what is generative ai?")
response
# Out:
# response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "**Generative AI**\n\nGenerative AI refers to a type of artificial intelligence that can create new data or content from scratch. It is different from traditional AI systems, which are typically trained to perform specific tasks based on existing data.\n\n**How Generative AI Works:**\n\n* **Input:** Generative AI models are trained on large datasets to learn the underlying patterns and structures of the data.\n* **Generation:** Once trained, the model can generate new data by combining its learned knowledge with random elements.\n* **Customization:** Generative AI models can be customized to generate specific types of data, such as images, text, music, or code.\n\n**Types of Generative AI:**\n\n* **Generative Adversarial Networks (GANs):** GANs use two competing networks to create realistic images and other data.\n* **Variational Autoencoders (VAEs):** VAEs learn a latent space that captures the essential features of the data, allowing it to generate new data by sampling from the latent space.\n* **Transformer Language Models (TLMs):** TLMs are large language models that can generate coherent and contextually relevant text.\n* **Diffusion Models:** Diffusion models gradually denoise an image or other data by adding random noise and then reversing the process to generate new data.\n\n**Applications of Generative AI:**\n\n* **Image and video creation:** Creating realistic images, videos, and animations.\n* **Text generation:** Generating natural language text, such as articles, stories, and code.\n* **Music composition:** Generating original musical compositions.\n* **Scientific discovery:** Generating new molecules, designs, and materials.\n* **Personalization:** Customizing experiences and products based on individual preferences.\n\n**Benefits of Generative AI:**\n\n* **Creativity:** Allows for the creation of original and unique data.\n* **Efficiency:** Can automate content creation tasks and save time.\n* **Exploration:** Enables the discovery of new possibilities and ideas.\n* **Customization:** Can personalize experiences and products to meet specific needs."
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "index": 0,
#           "safety_ratings": [
#             {
#               "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
#               "probability": "NEGLIGIBLE"
#             },
#             {
#               "category": "HARM_CATEGORY_HATE_SPEECH",
#               "probability": "NEGLIGIBLE"
#             },
#             {
#               "category": "HARM_CATEGORY_HARASSMENT",
#               "probability": "NEGLIGIBLE"
#             },
#             {
#               "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
#               "probability": "NEGLIGIBLE"
#             }
#           ]
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 6,
#         "candidates_token_count": 420,
#         "total_token_count": 426
#       }
#     }),
# )

# %%
response.text
# Out:
# '**Generative AI**\n\nGenerative AI refers to a type of artificial intelligence that can create new data or content from scratch. It is different from traditional AI systems, which are typically trained to perform specific tasks based on existing data.\n\n**How Generative AI Works:**\n\n* **Input:** Generative AI models are trained on large datasets to learn the underlying patterns and structures of the data.\n* **Generation:** Once trained, the model can generate new data by combining its learned knowledge with random elements.\n* **Customization:** Generative AI models can be customized to generate specific types of data, such as images, text, music, or code.\n\n**Types of Generative AI:**\n\n* **Generative Adversarial Networks (GANs):** GANs use two competing networks to create realistic images and other data.\n* **Variational Autoencoders (VAEs):** VAEs learn a latent space that captures the essential features of the data, allowing it to generate new data by sampling from the latent space.\n* **Transformer Language Models (TLMs):** TLMs are large language models that can generate coherent and contextually relevant text.\n* **Diffusion Models:** Diffusion models gradually denoise an image or other data by adding random noise and then reversing the process to generate new data.\n\n**Applications of Generative AI:**\n\n* **Image and video creation:** Creating realistic images, videos, and animations.\n* **Text generation:** Generating natural language text, such as articles, stories, and code.\n* **Music composition:** Generating original musical compositions.\n* **Scientific discovery:** Generating new molecules, designs, and materials.\n* **Personalization:** Customizing experiences and products based on individual preferences.\n\n**Benefits of Generative AI:**\n\n* **Creativity:** Allows for the creation of original and unique data.\n* **Efficiency:** Can automate content creation tasks and save time.\n* **Exploration:** Enables the discovery of new possibilities and ideas.\n* **Customization:** Can personalize experiences and products to meet specific needs.'
